# %%
# Importing necessary libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Loading the dataset into a Pandas DataFrame

# %%
df = pd.read_csv("Data/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv"
)

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...                              GeoLocation  ClassID  \
# 0               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 1               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 2               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 3               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 4               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# ...               ...  ...                                      ...      ...
# 53387           Value  ...                  (18.335765, -64.896335)       PA
# 53388           Value  ...                  (18.335765, -64.896335)       PA
# 53389           Value  ...                  (18.335765, -64.896335)       PA
# 53390           Value  ...                  (18.335765, -64.896335)       PA
# 53391           Value  ...                  (18.335765, -64.896335)       PA
#
#       TopicID QuestionID  DataValueTypeID  LocationID  \
# 0        OWS1       Q036            VALUE           1
# 1        OWS1       Q036            VALUE           1
# 2        OWS1       Q036            VALUE           1
# 3        OWS1       Q036            VALUE           1
# 4        OWS1       Q036            VALUE           1
# ...       ...        ...              ...         ...
# 53387     PA1       Q047            VALUE          78
# 53388     PA1       Q047            VALUE          78
# 53389     PA1       Q047            VALUE          78
# 53390     PA1       Q047            VALUE          78
# 53391     PA1       Q047            VALUE          78
#
#        StratificationCategory1                Stratification1  \
# 0                        Total                          Total
# 1                       Gender                           Male
# 2                       Gender                         Female
# 3                    Education          Less than high school
# 4                    Education           High school graduate
# ...                        ...                            ...
# 53387           Race/Ethnicity                          Asian
# 53388           Race/Ethnicity      Hawaiian/Pacific Islander
# 53389           Race/Ethnicity  American Indian/Alaska Native
# 53390           Race/Ethnicity                2 or more races
# 53391           Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 0                           OVR           OVERALL
# 1                           GEN              MALE
# 2                           GEN            FEMALE
# 3                           EDU             EDUHS
# 4                           EDU         EDUHSGRAD
# ...                         ...               ...
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH
#
# [53392 rows x 33 columns]

# %% [markdown]
#  # Summary of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
#  13  Data_Value_Footnote         5046 non-null   object
#  14  Low_Confidence_Limit        48346 non-null  float64
#  15  High_Confidence_Limit       48346 non-null  float64
#  16  Sample_Size                 48346 non-null  float64
#  17  Total                       1907 non-null   object
#  18  Age(years)                  11438 non-null  object
#  19  Education                   7628 non-null   object
#  20  Gender                      3814 non-null   object
#  21  Income                      13349 non-null  object
#  22  Race/Ethnicity              15256 non-null  object
#  23  GeoLocation                 52384 non-null  object
#  24  ClassID                     53392 non-null  object
#  25  TopicID                     53392 non-null  object
#  26  QuestionID                  53392 non-null  object
#  27  DataValueTypeID             53392 non-null  object
#  28  LocationID                  53392 non-null  int64
#  29  StratificationCategory1     53392 non-null  object
#  30  Stratification1             53392 non-null  object
#  31  StratificationCategoryId1   53392 non-null  object
#  32  StratificationID1           53392 non-null  object
# dtypes: float64(6), int64(3), object(24)
# memory usage: 13.4+ MB

# %%
df = df.drop(['Low_Confidence_Limit','High_Confidence_Limit ', 'Total', 'Data_Value_Alt', 'YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);
df = df.drop(['GeoLocation'],1)
# Out:
# C:\Users\Poppy Nevin\AppData\Local\Temp\ipykernel_26992\4273286801.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['Low_Confidence_Limit','High_Confidence_Limit ', 'Total', 'Data_Value_Alt', 'YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);
# C:\Users\Poppy Nevin\AppData\Local\Temp\ipykernel_26992\4273286801.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['GeoLocation'],1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   yearstart                53392 non-null  int64
#  1   locationabbr             53392 non-null  object
#  2   locationdesc             53392 non-null  object
#  3   question                 53392 non-null  object
#  4   data_value               48346 non-null  float64
#  5   sample_size              48346 non-null  float64
#  6   age(years)               11438 non-null  object
#  7   education                0 non-null      float64
#  8   gender                   3814 non-null   object
#  9   income                   13349 non-null  object
#  10  race/ethnicity           15256 non-null  object
#  11  locationid               53392 non-null  int64
#  12  stratificationcategory1  53392 non-null  object
#  13  stratification1          53392 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 5.7+ MB

# %%
df2=df.dropna(subset=['age(years)'])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11438 entries, 7 to 53376
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   yearstart                11438 non-null  int64
#  1   locationabbr             11438 non-null  object
#  2   locationdesc             11438 non-null  object
#  3   question                 11438 non-null  object
#  4   data_value               11438 non-null  float64
#  5   sample_size              11438 non-null  float64
#  6   age(years)               11438 non-null  object
#  7   education                0 non-null      float64
#  8   gender                   0 non-null      object
#  9   income                   0 non-null      object
#  10  race/ethnicity           0 non-null      object
#  11  locationid               11438 non-null  int64
#  12  stratificationcategory1  11438 non-null  object
#  13  stratification1          11438 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#           YearStart    Data_Value   Sample_Size    LocationID
# count  53392.000000  48346.000000   48346.00000  53392.000000
# mean    2013.281465     31.156681    3889.19286     30.282215
# std        1.693300     10.247033   19829.42129     16.821318
# min     2011.000000      0.900000      50.00000      1.000000
# 25%     2012.000000     24.100000     566.00000     17.000000
# 50%     2013.000000     30.700000    1209.00000     30.000000
# 75%     2015.000000     37.000000    2519.00000     44.000000
# max     2016.000000     77.600000  476876.00000     78.000000

# %% [markdown]
# ## Standardizing the column names

# %%
def lower_case_column_names(df):
    df.columns=[i.lower() for i in df.columns]
    return df

# %%
df=lower_case_column_names(df)
df
# Out:
#        yearstart locationabbr    locationdesc  \
# 0           2011           AL         Alabama
# 1           2011           AL         Alabama
# 2           2011           AL         Alabama
# 3           2011           AL         Alabama
# 4           2011           AL         Alabama
# ...          ...          ...             ...
# 53387       2016           VI  Virgin Islands
# 53388       2016           VI  Virgin Islands
# 53389       2016           VI  Virgin Islands
# 53390       2016           VI  Virgin Islands
# 53391       2016           VI  Virgin Islands
#
#                                                 question  data_value  \
# 0      Percent of adults aged 18 years and older who ...        32.0
# 1      Percent of adults aged 18 years and older who ...        32.3
# 2      Percent of adults aged 18 years and older who ...        31.8
# 3      Percent of adults aged 18 years and older who ...        33.6
# 4      Percent of adults aged 18 years and older who ...        32.8
# ...                                                  ...         ...
# 53387  Percent of adults who engage in no leisure-tim...         NaN
# 53388  Percent of adults who engage in no leisure-tim...         NaN
# 53389  Percent of adults who engage in no leisure-tim...         NaN
# 53390  Percent of adults who engage in no leisure-tim...         NaN
# 53391  Percent of adults who engage in no leisure-tim...         NaN
#
#        sample_size age(years)              education  gender income  \
# 0           7304.0        NaN                    NaN     NaN    NaN
# 1           2581.0        NaN                    NaN    Male    NaN
# 2           4723.0        NaN                    NaN  Female    NaN
# 3           1153.0        NaN  Less than high school     NaN    NaN
# 4           2402.0        NaN   High school graduate     NaN    NaN
# ...            ...        ...                    ...     ...    ...
# 53387          NaN        NaN                    NaN     NaN    NaN
# 53388          NaN        NaN                    NaN     NaN    NaN
# 53389          NaN        NaN                    NaN     NaN    NaN
# 53390          NaN        NaN                    NaN     NaN    NaN
# 53391          NaN        NaN                    NaN     NaN    NaN
#
#                       race/ethnicity  locationid stratificationcategory1  \
# 0                                NaN           1                   Total
# 1                                NaN           1                  Gender
# 2                                NaN           1                  Gender
# 3                                NaN           1               Education
# 4                                NaN           1               Education
# ...                              ...         ...                     ...
# 53387                          Asian          78          Race/Ethnicity
# 53388      Hawaiian/Pacific Islander          78          Race/Ethnicity
# 53389  American Indian/Alaska Native          78          Race/Ethnicity
# 53390                2 or more races          78          Race/Ethnicity
# 53391                          Other          78          Race/Ethnicity
#
#                      stratification1
# 0                              Total
# 1                               Male
# 2                             Female
# 3              Less than high school
# 4               High school graduate
# ...                              ...
# 53387                          Asian
# 53388      Hawaiian/Pacific Islander
# 53389  American Indian/Alaska Native
# 53390                2 or more races
# 53391                          Other
#
# [53392 rows x 14 columns]

# %% [markdown]
# ## Checking for duplicate & missing values

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.isna()
# Out:
#        yearstart  locationabbr  locationdesc  question  data_value  \
# 0          False         False         False     False       False
# 1          False         False         False     False       False
# 2          False         False         False     False       False
# 3          False         False         False     False       False
# 4          False         False         False     False       False
# ...          ...           ...           ...       ...         ...
# 53387      False         False         False     False        True
# 53388      False         False         False     False        True
# 53389      False         False         False     False        True
# 53390      False         False         False     False        True
# 53391      False         False         False     False        True
#
#        sample_size  age(years)  education  gender  income  race/ethnicity  \
# 0            False        True       True    True    True            True
# 1            False        True       True   False    True            True
# 2            False        True       True   False    True            True
# 3            False        True      False    True    True            True
# 4            False        True      False    True    True            True
# ...            ...         ...        ...     ...     ...             ...
# 53387         True        True       True    True    True           False
# 53388         True        True       True    True    True           False
# 53389         True        True       True    True    True           False
# 53390         True        True       True    True    True           False
# 53391         True        True       True    True    True           False
#
#        locationid  stratificationcategory1  stratification1
# 0           False                    False            False
# 1           False                    False            False
# 2           False                    False            False
# 3           False                    False            False
# 4           False                    False            False
# ...           ...                      ...              ...
# 53387       False                    False            False
# 53388       False                    False            False
# 53389       False                    False            False
# 53390       False                    False            False
# 53391       False                    False            False
#
# [53392 rows x 14 columns]

# %%
df['race/ethnicity'].value_counts()
# Out:
# Non-Hispanic White               1907
# Non-Hispanic Black               1907
# Hispanic                         1907
# Asian                            1907
# Hawaiian/Pacific Islander        1907
# American Indian/Alaska Native    1907
# 2 or more races                  1907
# Other                            1907
# Name: race/ethnicity, dtype: int64

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# yearstart                   0.000000
# locationabbr                0.000000
# locationdesc                0.000000
# question                    0.000000
# data_value                  9.450854
# sample_size                 9.450854
# age(years)                 78.577315
# education                  85.713215
# gender                     92.856608
# income                     74.998127
# race/ethnicity             71.426431
# locationid                  0.000000
# stratificationcategory1     0.000000
# stratification1             0.000000
# dtype: float64

# %% [markdown]
# ## Going by Alex's & Peter's new advice we would drop age, education, gender, income and race/ethnicity.
#
# ## So we can compare the

# %% [markdown]
# ## Removing outliers

# %%
def remove_outliers(df):
    for col in df.select_dtypes(include=np.number).columns:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)
        df.drop(df[(df[col] < lower_bound) | (df[col] > upper_bound)].index, inplace=True)

# %%
remove_outliers(df)
df
# Out:
#        yearstart locationabbr    locationdesc  \
# 1           2011           AL         Alabama
# 2           2011           AL         Alabama
# 3           2011           AL         Alabama
# 4           2011           AL         Alabama
# 5           2011           AL         Alabama
# ...          ...          ...             ...
# 53387       2016           VI  Virgin Islands
# 53388       2016           VI  Virgin Islands
# 53389       2016           VI  Virgin Islands
# 53390       2016           VI  Virgin Islands
# 53391       2016           VI  Virgin Islands
#
#                                                 question  data_value  \
# 1      Percent of adults aged 18 years and older who ...        32.3
# 2      Percent of adults aged 18 years and older who ...        31.8
# 3      Percent of adults aged 18 years and older who ...        33.6
# 4      Percent of adults aged 18 years and older who ...        32.8
# 5      Percent of adults aged 18 years and older who ...        33.8
# ...                                                  ...         ...
# 53387  Percent of adults who engage in no leisure-tim...         NaN
# 53388  Percent of adults who engage in no leisure-tim...         NaN
# 53389  Percent of adults who engage in no leisure-tim...         NaN
# 53390  Percent of adults who engage in no leisure-tim...         NaN
# 53391  Percent of adults who engage in no leisure-tim...         NaN
#
#        sample_size age(years)                         education  gender  \
# 1           2581.0        NaN                               NaN    Male
# 2           4723.0        NaN                               NaN  Female
# 3           1153.0        NaN             Less than high school     NaN
# 4           2402.0        NaN              High school graduate     NaN
# 5           1925.0        NaN  Some college or technical school     NaN
# ...            ...        ...                               ...     ...
# 53387          NaN        NaN                               NaN     NaN
# 53388          NaN        NaN                               NaN     NaN
# 53389          NaN        NaN                               NaN     NaN
# 53390          NaN        NaN                               NaN     NaN
# 53391          NaN        NaN                               NaN     NaN
#
#       income                 race/ethnicity  locationid  \
# 1        NaN                            NaN           1
# 2        NaN                            NaN           1
# 3        NaN                            NaN           1
# 4        NaN                            NaN           1
# 5        NaN                            NaN           1
# ...      ...                            ...         ...
# 53387    NaN                          Asian          78
# 53388    NaN      Hawaiian/Pacific Islander          78
# 53389    NaN  American Indian/Alaska Native          78
# 53390    NaN                2 or more races          78
# 53391    NaN                          Other          78
#
#       stratificationcategory1                   stratification1
# 1                      Gender                              Male
# 2                      Gender                            Female
# 3                   Education             Less than high school
# 4                   Education              High school graduate
# 5                   Education  Some college or technical school
# ...                       ...                               ...
# 53387          Race/Ethnicity                             Asian
# 53388          Race/Ethnicity         Hawaiian/Pacific Islander
# 53389          Race/Ethnicity     American Indian/Alaska Native
# 53390          Race/Ethnicity                   2 or more races
# 53391          Race/Ethnicity                             Other
#
# [47875 rows x 14 columns]

# %% [markdown]
# ## Standardizing the text in the data

# %%
def standardize_text(df):
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].str.lower()

# %%
standardize_text(df)
df
# Out:
#        yearstart locationabbr    locationdesc  \
# 1           2011           al         alabama
# 2           2011           al         alabama
# 3           2011           al         alabama
# 4           2011           al         alabama
# 5           2011           al         alabama
# ...          ...          ...             ...
# 53387       2016           vi  virgin islands
# 53388       2016           vi  virgin islands
# 53389       2016           vi  virgin islands
# 53390       2016           vi  virgin islands
# 53391       2016           vi  virgin islands
#
#                                                 question  data_value  \
# 1      percent of adults aged 18 years and older who ...        32.3
# 2      percent of adults aged 18 years and older who ...        31.8
# 3      percent of adults aged 18 years and older who ...        33.6
# 4      percent of adults aged 18 years and older who ...        32.8
# 5      percent of adults aged 18 years and older who ...        33.8
# ...                                                  ...         ...
# 53387  percent of adults who engage in no leisure-tim...         NaN
# 53388  percent of adults who engage in no leisure-tim...         NaN
# 53389  percent of adults who engage in no leisure-tim...         NaN
# 53390  percent of adults who engage in no leisure-tim...         NaN
# 53391  percent of adults who engage in no leisure-tim...         NaN
#
#        sample_size age(years)                         education  gender  \
# 1           2581.0        NaN                               NaN    male
# 2           4723.0        NaN                               NaN  female
# 3           1153.0        NaN             less than high school     NaN
# 4           2402.0        NaN              high school graduate     NaN
# 5           1925.0        NaN  some college or technical school     NaN
# ...            ...        ...                               ...     ...
# 53387          NaN        NaN                               NaN     NaN
# 53388          NaN        NaN                               NaN     NaN
# 53389          NaN        NaN                               NaN     NaN
# 53390          NaN        NaN                               NaN     NaN
# 53391          NaN        NaN                               NaN     NaN
#
#       income                 race/ethnicity  locationid  \
# 1        NaN                            NaN           1
# 2        NaN                            NaN           1
# 3        NaN                            NaN           1
# 4        NaN                            NaN           1
# 5        NaN                            NaN           1
# ...      ...                            ...         ...
# 53387    NaN                          asian          78
# 53388    NaN      hawaiian/pacific islander          78
# 53389    NaN  american indian/alaska native          78
# 53390    NaN                2 or more races          78
# 53391    NaN                          other          78
#
#       stratificationcategory1                   stratification1
# 1                      gender                              male
# 2                      gender                            female
# 3                   education             less than high school
# 4                   education              high school graduate
# 5                   education  some college or technical school
# ...                       ...                               ...
# 53387          race/ethnicity                             asian
# 53388          race/ethnicity         hawaiian/pacific islander
# 53389          race/ethnicity     american indian/alaska native
# 53390          race/ethnicity                   2 or more races
# 53391          race/ethnicity                             other
#
# [47875 rows x 14 columns]

# %% [markdown]
# # Data split for Numerical and Categorical variables

# %%
numerical_columns = df.select_dtypes(include=['int', 'float']).columns
numerical = df[numerical_columns]
numerical
# Out:
#        yearstart  data_value  sample_size  locationid
# 1           2011        32.3       2581.0           1
# 2           2011        31.8       4723.0           1
# 3           2011        33.6       1153.0           1
# 4           2011        32.8       2402.0           1
# 5           2011        33.8       1925.0           1
# ...          ...         ...          ...         ...
# 53387       2016         NaN          NaN          78
# 53388       2016         NaN          NaN          78
# 53389       2016         NaN          NaN          78
# 53390       2016         NaN          NaN          78
# 53391       2016         NaN          NaN          78
#
# [47875 rows x 4 columns]

# %%
numerical = numerical.fillna(numerical.mean())
numerical
# Out:
#        yearstart  data_value  sample_size  locationid
# 1           2011   32.300000  2581.000000           1
# 2           2011   31.800000  4723.000000           1
# 3           2011   33.600000  1153.000000           1
# 4           2011   32.800000  2402.000000           1
# 5           2011   33.800000  1925.000000           1
# ...          ...         ...          ...         ...
# 53387       2016   30.682096  1419.887249          78
# 53388       2016   30.682096  1419.887249          78
# 53389       2016   30.682096  1419.887249          78
# 53390       2016   30.682096  1419.887249          78
# 53391       2016   30.682096  1419.887249          78
#
# [47875 rows x 4 columns]

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical = df[categorical_columns]
categorical
# Out:
#       locationabbr    locationdesc  \
# 1               al         alabama
# 2               al         alabama
# 3               al         alabama
# 4               al         alabama
# 5               al         alabama
# ...            ...             ...
# 53387           vi  virgin islands
# 53388           vi  virgin islands
# 53389           vi  virgin islands
# 53390           vi  virgin islands
# 53391           vi  virgin islands
#
#                                                 question age(years)  \
# 1      percent of adults aged 18 years and older who ...        NaN
# 2      percent of adults aged 18 years and older who ...        NaN
# 3      percent of adults aged 18 years and older who ...        NaN
# 4      percent of adults aged 18 years and older who ...        NaN
# 5      percent of adults aged 18 years and older who ...        NaN
# ...                                                  ...        ...
# 53387  percent of adults who engage in no leisure-tim...        NaN
# 53388  percent of adults who engage in no leisure-tim...        NaN
# 53389  percent of adults who engage in no leisure-tim...        NaN
# 53390  percent of adults who engage in no leisure-tim...        NaN
# 53391  percent of adults who engage in no leisure-tim...        NaN
#
#                               education  gender income  \
# 1                                   NaN    male    NaN
# 2                                   NaN  female    NaN
# 3                 less than high school     NaN    NaN
# 4                  high school graduate     NaN    NaN
# 5      some college or technical school     NaN    NaN
# ...                                 ...     ...    ...
# 53387                               NaN     NaN    NaN
# 53388                               NaN     NaN    NaN
# 53389                               NaN     NaN    NaN
# 53390                               NaN     NaN    NaN
# 53391                               NaN     NaN    NaN
#
#                       race/ethnicity stratificationcategory1  \
# 1                                NaN                  gender
# 2                                NaN                  gender
# 3                                NaN               education
# 4                                NaN               education
# 5                                NaN               education
# ...                              ...                     ...
# 53387                          asian          race/ethnicity
# 53388      hawaiian/pacific islander          race/ethnicity
# 53389  american indian/alaska native          race/ethnicity
# 53390                2 or more races          race/ethnicity
# 53391                          other          race/ethnicity
#
#                         stratification1
# 1                                  male
# 2                                female
# 3                 less than high school
# 4                  high school graduate
# 5      some college or technical school
# ...                                 ...
# 53387                             asian
# 53388         hawaiian/pacific islander
# 53389     american indian/alaska native
# 53390                   2 or more races
# 53391                             other
#
# [47875 rows x 10 columns]

# %%
categorical = categorical.fillna(categorical.mode())

# %%
categorical
# Out:
#       locationabbr    locationdesc  \
# 1               al         alabama
# 2               al         alabama
# 3               al         alabama
# 4               al         alabama
# 5               al         alabama
# ...            ...             ...
# 53387           vi  virgin islands
# 53388           vi  virgin islands
# 53389           vi  virgin islands
# 53390           vi  virgin islands
# 53391           vi  virgin islands
#
#                                                 question age(years)  \
# 1      percent of adults aged 18 years and older who ...        NaN
# 2      percent of adults aged 18 years and older who ...        NaN
# 3      percent of adults aged 18 years and older who ...        NaN
# 4      percent of adults aged 18 years and older who ...        NaN
# 5      percent of adults aged 18 years and older who ...        NaN
# ...                                                  ...        ...
# 53387  percent of adults who engage in no leisure-tim...        NaN
# 53388  percent of adults who engage in no leisure-tim...        NaN
# 53389  percent of adults who engage in no leisure-tim...        NaN
# 53390  percent of adults who engage in no leisure-tim...        NaN
# 53391  percent of adults who engage in no leisure-tim...        NaN
#
#                               education  gender income  \
# 1                                   NaN    male    NaN
# 2                                   NaN  female    NaN
# 3                 less than high school     NaN    NaN
# 4                  high school graduate     NaN    NaN
# 5      some college or technical school     NaN    NaN
# ...                                 ...     ...    ...
# 53387                               NaN     NaN    NaN
# 53388                               NaN     NaN    NaN
# 53389                               NaN     NaN    NaN
# 53390                               NaN     NaN    NaN
# 53391                               NaN     NaN    NaN
#
#                       race/ethnicity stratificationcategory1  \
# 1                                NaN                  gender
# 2                                NaN                  gender
# 3                                NaN               education
# 4                                NaN               education
# 5                                NaN               education
# ...                              ...                     ...
# 53387                          asian          race/ethnicity
# 53388      hawaiian/pacific islander          race/ethnicity
# 53389  american indian/alaska native          race/ethnicity
# 53390                2 or more races          race/ethnicity
# 53391                          other          race/ethnicity
#
#                         stratification1
# 1                                  male
# 2                                female
# 3                 less than high school
# 4                  high school graduate
# 5      some college or technical school
# ...                                 ...
# 53387                             asian
# 53388         hawaiian/pacific islander
# 53389     american indian/alaska native
# 53390                   2 or more races
# 53391                             other
#
# [47875 rows x 10 columns]

# %% [markdown]
# # One-Hot Encoding for Categorical variables

# %%
categorical.columns
# Out:
# Index(['locationabbr', 'locationdesc', 'question', 'age(years)', 'education',
#        'gender', 'income', 'race/ethnicity', 'stratificationcategory1',
#        'stratification1'],
#       dtype='object')

# %%
df['stratification1'].unique()
# Out:
# array(['male', 'female', 'less than high school', 'high school graduate',
#        'some college or technical school', 'college graduate', '18 - 24',
#        '25 - 34', '35 - 44', '45 - 54', '55 - 64', '65 or older',
#        'less than $15,000', '$15,000 - $24,999', '$25,000 - $34,999',
#        '$35,000 - $49,999', '$50,000 - $74,999', '$75,000 or greater',
#        'data not reported', 'non-hispanic white', 'non-hispanic black',
#        'hispanic', 'asian', 'hawaiian/pacific islander',
#        'american indian/alaska native', '2 or more races', 'other',
#        'total'], dtype=object)

# %%
#income
in_map = {'less than $15,000':0, '$15,000 - $24,999':1, '$25,000 - $34,999':2,'$35,000 - $49,999':3, '$50,000 - $74,999':4, 
          '$75,000 or greater':5, 'data not reported':6}
in_map
df['income'] = df['income'].map(in_map)

# %%
#education
ed_map = {'less than high school': 0, 'high school graduate':1, 'some college or technical school':2,'college graduate':3}
ed_map
df['education'] = df['education'].map(ed_map)

# %%
#race/ethnicity
rc_map = {'non-hispanic white': 0, 'non-hispanic black':1, 'hispanic':2,'asian':3, 'hawaiian/pacific islander':4,
       'american indian/alaska native':5, '2 or more races':6, 'other':7}
rc_map
df['race/ethnicity'] = df['race/ethnicity'].map(rc_map)

# %%
#age(years)
ag_map = {'18 - 24': 0,  '25 - 34':1,  '35 - 44':2,'45 - 54':3, '55 - 64':4, '65 or older':5}
ag_map
df['age(years)'] = df['age(years)'].map(ag_map)

# %%
df_dummies = pd.get_dummies(df['gender'], sparse=1,drop_first=1)

# %%
df
# Out:
#        yearstart locationabbr    locationdesc  \
# 1           2011           al         alabama
# 2           2011           al         alabama
# 3           2011           al         alabama
# 4           2011           al         alabama
# 5           2011           al         alabama
# ...          ...          ...             ...
# 53387       2016           vi  virgin islands
# 53388       2016           vi  virgin islands
# 53389       2016           vi  virgin islands
# 53390       2016           vi  virgin islands
# 53391       2016           vi  virgin islands
#
#                                                 question  data_value  \
# 1      percent of adults aged 18 years and older who ...        32.3
# 2      percent of adults aged 18 years and older who ...        31.8
# 3      percent of adults aged 18 years and older who ...        33.6
# 4      percent of adults aged 18 years and older who ...        32.8
# 5      percent of adults aged 18 years and older who ...        33.8
# ...                                                  ...         ...
# 53387  percent of adults who engage in no leisure-tim...         NaN
# 53388  percent of adults who engage in no leisure-tim...         NaN
# 53389  percent of adults who engage in no leisure-tim...         NaN
# 53390  percent of adults who engage in no leisure-tim...         NaN
# 53391  percent of adults who engage in no leisure-tim...         NaN
#
#        sample_size  age(years)  education  gender  income  race/ethnicity  \
# 1           2581.0         NaN        NaN    male     NaN             NaN
# 2           4723.0         NaN        NaN  female     NaN             NaN
# 3           1153.0         NaN        0.0     NaN     NaN             NaN
# 4           2402.0         NaN        1.0     NaN     NaN             NaN
# 5           1925.0         NaN        2.0     NaN     NaN             NaN
# ...            ...         ...        ...     ...     ...             ...
# 53387          NaN         NaN        NaN     NaN     NaN             3.0
# 53388          NaN         NaN        NaN     NaN     NaN             4.0
# 53389          NaN         NaN        NaN     NaN     NaN             5.0
# 53390          NaN         NaN        NaN     NaN     NaN             6.0
# 53391          NaN         NaN        NaN     NaN     NaN             7.0
#
#        locationid stratificationcategory1                   stratification1
# 1               1                  gender                              male
# 2               1                  gender                            female
# 3               1               education             less than high school
# 4               1               education              high school graduate
# 5               1               education  some college or technical school
# ...           ...                     ...                               ...
# 53387          78          race/ethnicity                             asian
# 53388          78          race/ethnicity         hawaiian/pacific islander
# 53389          78          race/ethnicity     american indian/alaska native
# 53390          78          race/ethnicity                   2 or more races
# 53391          78          race/ethnicity                             other
#
# [47875 rows x 14 columns]

# %% [markdown]
# # Ploting distributions of numerical data

# %%
for col in numerical.columns:
    sns.displot(numerical[col])
    plt.show()

# %%
numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47875 entries, 1 to 53391
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   yearstart    47875 non-null  int64
#  1   data_value   47875 non-null  float64
#  2   sample_size  47875 non-null  float64
#  3   locationid   47875 non-null  int64
# dtypes: float64(2), int64(2)
# memory usage: 2.8 MB

# %%
numerical.hist(figsize=(20,15), grid=False)
plt.show()

# %% [markdown]
# # Plot relationships between Numerical variables

# %%
sns.pairplot(numerical)

# %%
numerical.corr()
# Out:
#              yearstart  data_value  sample_size  locationid
# yearstart     1.000000    0.004610    -0.040295    0.047854
# data_value    0.004610    1.000000    -0.023037    0.000848
# sample_size  -0.040295   -0.023037     1.000000   -0.001613
# locationid    0.047854    0.000848    -0.001613    1.000000

# %%
corr = numerical.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, 
        annot=True, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['yearstart', 'locationabbr', 'locationdesc', 'question', 'data_value',
#        'sample_size', 'age(years)', 'education', 'gender', 'income',
#        'race/ethnicity', 'locationid', 'stratificationcategory1',
#        'stratification1'],
#       dtype='object')

# %%
X = numerical.drop('data_value', axis=1)
y = numerical['data_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
X_train.head(3)
# Out:
#        yearstart  sample_size  locationid
# 26196       2013   584.000000          41
# 16725       2013   580.000000          28
# 29961       2011  1419.887249          48

# %% [markdown]
# # Creating the Model

# %%
# Specify the model
model = LinearRegression()

# Fit the model on the training data
model.fit(X_train, y_train)

# Predict the response on the test data
y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluating the model using mean squared error and R-squared

# %%
mse = mse(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 80.64352287583952
# R-squared: 0.0005878116310155113

# %%
#Confirming target variable = data_value
