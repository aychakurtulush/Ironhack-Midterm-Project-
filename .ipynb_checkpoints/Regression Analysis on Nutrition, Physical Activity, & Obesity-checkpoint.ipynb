# %%
# Importing necessary libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Loading the dataset into a Pandas DataFrame

# %%
df = pd.read_csv("Data/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv"
)

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...                              GeoLocation  ClassID  \
# 0               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 1               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 2               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 3               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 4               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# ...               ...  ...                                      ...      ...
# 53387           Value  ...                  (18.335765, -64.896335)       PA
# 53388           Value  ...                  (18.335765, -64.896335)       PA
# 53389           Value  ...                  (18.335765, -64.896335)       PA
# 53390           Value  ...                  (18.335765, -64.896335)       PA
# 53391           Value  ...                  (18.335765, -64.896335)       PA
#
#       TopicID QuestionID  DataValueTypeID  LocationID  \
# 0        OWS1       Q036            VALUE           1
# 1        OWS1       Q036            VALUE           1
# 2        OWS1       Q036            VALUE           1
# 3        OWS1       Q036            VALUE           1
# 4        OWS1       Q036            VALUE           1
# ...       ...        ...              ...         ...
# 53387     PA1       Q047            VALUE          78
# 53388     PA1       Q047            VALUE          78
# 53389     PA1       Q047            VALUE          78
# 53390     PA1       Q047            VALUE          78
# 53391     PA1       Q047            VALUE          78
#
#        StratificationCategory1                Stratification1  \
# 0                        Total                          Total
# 1                       Gender                           Male
# 2                       Gender                         Female
# 3                    Education          Less than high school
# 4                    Education           High school graduate
# ...                        ...                            ...
# 53387           Race/Ethnicity                          Asian
# 53388           Race/Ethnicity      Hawaiian/Pacific Islander
# 53389           Race/Ethnicity  American Indian/Alaska Native
# 53390           Race/Ethnicity                2 or more races
# 53391           Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 0                           OVR           OVERALL
# 1                           GEN              MALE
# 2                           GEN            FEMALE
# 3                           EDU             EDUHS
# 4                           EDU         EDUHSGRAD
# ...                         ...               ...
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH
#
# [53392 rows x 33 columns]

# %% [markdown]
#  # Summary of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
#  13  Data_Value_Footnote         5046 non-null   object
#  14  Low_Confidence_Limit        48346 non-null  float64
#  15  High_Confidence_Limit       48346 non-null  float64
#  16  Sample_Size                 48346 non-null  float64
#  17  Total                       1907 non-null   object
#  18  Age(years)                  11438 non-null  object
#  19  Education                   7628 non-null   object
#  20  Gender                      3814 non-null   object
#  21  Income                      13349 non-null  object
#  22  Race/Ethnicity              15256 non-null  object
#  23  GeoLocation                 52384 non-null  object
#  24  ClassID                     53392 non-null  object
#  25  TopicID                     53392 non-null  object
#  26  QuestionID                  53392 non-null  object
#  27  DataValueTypeID             53392 non-null  object
#  28  LocationID                  53392 non-null  int64
#  29  StratificationCategory1     53392 non-null  object
#  30  Stratification1             53392 non-null  object
#  31  StratificationCategoryId1   53392 non-null  object
#  32  StratificationID1           53392 non-null  object
# dtypes: float64(6), int64(3), object(24)
# memory usage: 13.4+ MB

# %%
df = df.drop(['Low_Confidence_Limit','High_Confidence_Limit ', 'Total', 'Data_Value_Alt', 'YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);
df = df.drop(['GeoLocation', 'Question', 'StratificationCategory1', 'Stratification1', 'Gender'],1)
# Out:
# C:\Users\kurtu\AppData\Local\Temp\ipykernel_2484\656730159.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['Low_Confidence_Limit','High_Confidence_Limit ', 'Total', 'Data_Value_Alt', 'YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);
# C:\Users\kurtu\AppData\Local\Temp\ipykernel_2484\656730159.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['GeoLocation', 'Question', 'StratificationCategory1', 'Stratification1', 'Gender'],1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   YearStart       53392 non-null  int64
#  1   LocationAbbr    53392 non-null  object
#  2   LocationDesc    53392 non-null  object
#  3   Data_Value      48346 non-null  float64
#  4   Sample_Size     48346 non-null  float64
#  5   Age(years)      11438 non-null  object
#  6   Education       7628 non-null   object
#  7   Income          13349 non-null  object
#  8   Race/Ethnicity  15256 non-null  object
#  9   LocationID      53392 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 4.1+ MB

# %%
df=df.dropna(subset=['Race/Ethnicity'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15256 entries, 20 to 53391
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   YearStart       15256 non-null  int64
#  1   LocationAbbr    15256 non-null  object
#  2   LocationDesc    15256 non-null  object
#  3   Data_Value      10210 non-null  float64
#  4   Sample_Size     10210 non-null  float64
#  5   Age(years)      0 non-null      object
#  6   Education       0 non-null      object
#  7   Income          0 non-null      object
#  8   Race/Ethnicity  15256 non-null  object
#  9   LocationID      15256 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#           YearStart    Data_Value    Sample_Size    LocationID
# count  15256.000000  10210.000000   10210.000000  15256.000000
# mean    2013.281594     31.191557    3027.495201     30.280021
# std        1.693342     10.525107   20563.627571     16.822991
# min     2011.000000      0.900000      50.000000      1.000000
# 25%     2012.000000     24.025000      93.000000     17.000000
# 50%     2013.000000     30.900000     228.000000     30.000000
# 75%     2015.000000     37.200000    1522.000000     44.000000
# max     2016.000000     77.600000  374997.000000     78.000000

# %% [markdown]
# ## Standardizing the column names

# %%
def lower_case_column_names(df):
    df.columns=[i.lower() for i in df.columns]
    return df

# %%
df=lower_case_column_names(df)
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 20          2011           AL         Alabama        29.8       5042.0
# 21          2011           AL         Alabama        40.1       1878.0
# 22          2011           AL         Alabama        28.6        115.0
# 23          2011           AL         Alabama         NaN          NaN
# 24          2011           AL         Alabama         NaN          NaN
# ...          ...          ...             ...         ...          ...
# 53387       2016           VI  Virgin Islands         NaN          NaN
# 53388       2016           VI  Virgin Islands         NaN          NaN
# 53389       2016           VI  Virgin Islands         NaN          NaN
# 53390       2016           VI  Virgin Islands         NaN          NaN
# 53391       2016           VI  Virgin Islands         NaN          NaN
#
#       age(years) education income                 race/ethnicity  locationid
# 20           NaN       NaN    NaN             Non-Hispanic White           1
# 21           NaN       NaN    NaN             Non-Hispanic Black           1
# 22           NaN       NaN    NaN                       Hispanic           1
# 23           NaN       NaN    NaN                          Asian           1
# 24           NaN       NaN    NaN      Hawaiian/Pacific Islander           1
# ...          ...       ...    ...                            ...         ...
# 53387        NaN       NaN    NaN                          Asian          78
# 53388        NaN       NaN    NaN      Hawaiian/Pacific Islander          78
# 53389        NaN       NaN    NaN  American Indian/Alaska Native          78
# 53390        NaN       NaN    NaN                2 or more races          78
# 53391        NaN       NaN    NaN                          Other          78
#
# [15256 rows x 10 columns]

# %% [markdown]
# ## Checking for duplicate & missing values

# %%
print(df.duplicated().sum())
# Out:
# 4191

# %%
df.isna()
# Out:
#        yearstart  locationabbr  locationdesc  data_value  sample_size  \
# 20         False         False         False       False        False
# 21         False         False         False       False        False
# 22         False         False         False       False        False
# 23         False         False         False        True         True
# 24         False         False         False        True         True
# ...          ...           ...           ...         ...          ...
# 53387      False         False         False        True         True
# 53388      False         False         False        True         True
# 53389      False         False         False        True         True
# 53390      False         False         False        True         True
# 53391      False         False         False        True         True
#
#        age(years)  education  income  race/ethnicity  locationid
# 20           True       True    True           False       False
# 21           True       True    True           False       False
# 22           True       True    True           False       False
# 23           True       True    True           False       False
# 24           True       True    True           False       False
# ...           ...        ...     ...             ...         ...
# 53387        True       True    True           False       False
# 53388        True       True    True           False       False
# 53389        True       True    True           False       False
# 53390        True       True    True           False       False
# 53391        True       True    True           False       False
#
# [15256 rows x 10 columns]

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# yearstart           0.000000
# locationabbr        0.000000
# locationdesc        0.000000
# data_value         33.075511
# sample_size        33.075511
# age(years)        100.000000
# education         100.000000
# income            100.000000
# race/ethnicity      0.000000
# locationid          0.000000
# dtype: float64

# %%
#df = df.drop(['age(years)', 'education', 'gender', 'income', 'race/ethnicity'],1)

# %% [markdown]
# ## Going by Alex's & Peter's new advice we would drop age, education, gender, income and race/ethnicity.
#
# ## So we can compare the

# %% [markdown]
# ## Removing outliers

# %%
def remove_outliers(df):
    for col in df.select_dtypes(include=np.number).columns:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)
        df.drop(df[(df[col] < lower_bound) | (df[col] > upper_bound)].index, inplace=True)

# %%
remove_outliers(df)
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 21          2011           AL         Alabama        40.1       1878.0
# 22          2011           AL         Alabama        28.6        115.0
# 23          2011           AL         Alabama         NaN          NaN
# 24          2011           AL         Alabama         NaN          NaN
# 25          2011           AL         Alabama        32.9         61.0
# ...          ...          ...             ...         ...          ...
# 53387       2016           VI  Virgin Islands         NaN          NaN
# 53388       2016           VI  Virgin Islands         NaN          NaN
# 53389       2016           VI  Virgin Islands         NaN          NaN
# 53390       2016           VI  Virgin Islands         NaN          NaN
# 53391       2016           VI  Virgin Islands         NaN          NaN
#
#       age(years) education income                 race/ethnicity  locationid
# 21           NaN       NaN    NaN             Non-Hispanic Black           1
# 22           NaN       NaN    NaN                       Hispanic           1
# 23           NaN       NaN    NaN                          Asian           1
# 24           NaN       NaN    NaN      Hawaiian/Pacific Islander           1
# 25           NaN       NaN    NaN  American Indian/Alaska Native           1
# ...          ...       ...    ...                            ...         ...
# 53387        NaN       NaN    NaN                          Asian          78
# 53388        NaN       NaN    NaN      Hawaiian/Pacific Islander          78
# 53389        NaN       NaN    NaN  American Indian/Alaska Native          78
# 53390        NaN       NaN    NaN                2 or more races          78
# 53391        NaN       NaN    NaN                          Other          78
#
# [13286 rows x 10 columns]

# %% [markdown]
# ## Standardizing the text in the data

# %%
def standardize_text(df):
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].str.lower()

# %%
standardize_text(df)
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 21          2011           al         alabama        40.1       1878.0
# 22          2011           al         alabama        28.6        115.0
# 23          2011           al         alabama         NaN          NaN
# 24          2011           al         alabama         NaN          NaN
# 25          2011           al         alabama        32.9         61.0
# ...          ...          ...             ...         ...          ...
# 53387       2016           vi  virgin islands         NaN          NaN
# 53388       2016           vi  virgin islands         NaN          NaN
# 53389       2016           vi  virgin islands         NaN          NaN
# 53390       2016           vi  virgin islands         NaN          NaN
# 53391       2016           vi  virgin islands         NaN          NaN
#
#       age(years) education income                 race/ethnicity  locationid
# 21           NaN       NaN    NaN             non-hispanic black           1
# 22           NaN       NaN    NaN                       hispanic           1
# 23           NaN       NaN    NaN                          asian           1
# 24           NaN       NaN    NaN      hawaiian/pacific islander           1
# 25           NaN       NaN    NaN  american indian/alaska native           1
# ...          ...       ...    ...                            ...         ...
# 53387        NaN       NaN    NaN                          asian          78
# 53388        NaN       NaN    NaN      hawaiian/pacific islander          78
# 53389        NaN       NaN    NaN  american indian/alaska native          78
# 53390        NaN       NaN    NaN                2 or more races          78
# 53391        NaN       NaN    NaN                          other          78
#
# [13286 rows x 10 columns]

# %% [markdown]
# # Data split for Numerical and Categorical variables

# %%
numerical_columns = df.select_dtypes(include=['int', 'float']).columns
numerical = df[numerical_columns]
numerical
# Out:
#        yearstart  data_value  sample_size  locationid
# 21          2011        40.1       1878.0           1
# 22          2011        28.6        115.0           1
# 23          2011         NaN          NaN           1
# 24          2011         NaN          NaN           1
# 25          2011        32.9         61.0           1
# ...          ...         ...          ...         ...
# 53387       2016         NaN          NaN          78
# 53388       2016         NaN          NaN          78
# 53389       2016         NaN          NaN          78
# 53390       2016         NaN          NaN          78
# 53391       2016         NaN          NaN          78
#
# [13286 rows x 4 columns]

# %%
numerical = numerical.fillna(numerical.mean())
numerical
# Out:
#        yearstart  data_value  sample_size  locationid
# 21          2011   40.100000  1878.000000           1
# 22          2011   28.600000   115.000000           1
# 23          2011   30.848786   462.390413           1
# 24          2011   30.848786   462.390413           1
# 25          2011   32.900000    61.000000           1
# ...          ...         ...          ...         ...
# 53387       2016   30.848786   462.390413          78
# 53388       2016   30.848786   462.390413          78
# 53389       2016   30.848786   462.390413          78
# 53390       2016   30.848786   462.390413          78
# 53391       2016   30.848786   462.390413          78
#
# [13286 rows x 4 columns]

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical = df[categorical_columns]
categorical
# Out:
#       locationabbr    locationdesc age(years) education income  \
# 21              al         alabama        NaN       NaN    NaN
# 22              al         alabama        NaN       NaN    NaN
# 23              al         alabama        NaN       NaN    NaN
# 24              al         alabama        NaN       NaN    NaN
# 25              al         alabama        NaN       NaN    NaN
# ...            ...             ...        ...       ...    ...
# 53387           vi  virgin islands        NaN       NaN    NaN
# 53388           vi  virgin islands        NaN       NaN    NaN
# 53389           vi  virgin islands        NaN       NaN    NaN
# 53390           vi  virgin islands        NaN       NaN    NaN
# 53391           vi  virgin islands        NaN       NaN    NaN
#
#                       race/ethnicity
# 21                non-hispanic black
# 22                          hispanic
# 23                             asian
# 24         hawaiian/pacific islander
# 25     american indian/alaska native
# ...                              ...
# 53387                          asian
# 53388      hawaiian/pacific islander
# 53389  american indian/alaska native
# 53390                2 or more races
# 53391                          other
#
# [13286 rows x 6 columns]

# %%
categorical = categorical.fillna(categorical.mode())

# %%
categorical
# Out:
#       locationabbr    locationdesc age(years) education income  \
# 21              al         alabama        NaN       NaN    NaN
# 22              al         alabama        NaN       NaN    NaN
# 23              al         alabama        NaN       NaN    NaN
# 24              al         alabama        NaN       NaN    NaN
# 25              al         alabama        NaN       NaN    NaN
# ...            ...             ...        ...       ...    ...
# 53387           vi  virgin islands        NaN       NaN    NaN
# 53388           vi  virgin islands        NaN       NaN    NaN
# 53389           vi  virgin islands        NaN       NaN    NaN
# 53390           vi  virgin islands        NaN       NaN    NaN
# 53391           vi  virgin islands        NaN       NaN    NaN
#
#                       race/ethnicity
# 21                non-hispanic black
# 22                          hispanic
# 23                             asian
# 24         hawaiian/pacific islander
# 25     american indian/alaska native
# ...                              ...
# 53387                          asian
# 53388      hawaiian/pacific islander
# 53389  american indian/alaska native
# 53390                2 or more races
# 53391                          other
#
# [13286 rows x 6 columns]

# %% [markdown]
# # One-Hot Encoding for Categorical variables

# %%
categorical.columns
# Out:
# Index(['locationabbr', 'locationdesc', 'age(years)', 'education', 'income',
#        'race/ethnicity'],
#       dtype='object')

# %%
#income
in_map = {'less than $15,000':0, '$15,000 - $24,999':1, '$25,000 - $34,999':2,'$35,000 - $49,999':3, '$50,000 - $74,999':4, 
          '$75,000 or greater':5, 'data not reported':6}
in_map
df['income'] = df['income'].map(in_map)

# %%
#education
ed_map = {'less than high school': 0, 'high school graduate':1, 'some college or technical school':2,'college graduate':3}
ed_map
df['education'] = df['education'].map(ed_map)

# %%
#race/ethnicity
rc_map = {'non-hispanic white': 0, 'non-hispanic black':1, 'hispanic':2,'asian':3, 'hawaiian/pacific islander':4,
       'american indian/alaska native':5, '2 or more races':6, 'other':7}
rc_map
df['race/ethnicity'] = df['race/ethnicity'].map(rc_map)

# %%
#age(years)
#ag_map = {'18 - 24': 0,  '25 - 34':1,  '35 - 44':2,'45 - 54':3, '55 - 64':4, '65 or older':5}
#ag_map
#df['age(years)'] = df['age(years)'].map(ag_map)

# %%
#df_dummies = pd.get_dummies(df['gender'], sparse=1,drop_first=1)

# %%
df
# Out:
#        yearstart locationabbr    locationdesc  data_value  sample_size  \
# 21          2011           al         alabama        40.1       1878.0
# 22          2011           al         alabama        28.6        115.0
# 23          2011           al         alabama         NaN          NaN
# 24          2011           al         alabama         NaN          NaN
# 25          2011           al         alabama        32.9         61.0
# ...          ...          ...             ...         ...          ...
# 53387       2016           vi  virgin islands         NaN          NaN
# 53388       2016           vi  virgin islands         NaN          NaN
# 53389       2016           vi  virgin islands         NaN          NaN
# 53390       2016           vi  virgin islands         NaN          NaN
# 53391       2016           vi  virgin islands         NaN          NaN
#
#       age(years)  education  income  race/ethnicity  locationid
# 21           NaN        NaN     NaN               1           1
# 22           NaN        NaN     NaN               2           1
# 23           NaN        NaN     NaN               3           1
# 24           NaN        NaN     NaN               4           1
# 25           NaN        NaN     NaN               5           1
# ...          ...        ...     ...             ...         ...
# 53387        NaN        NaN     NaN               3          78
# 53388        NaN        NaN     NaN               4          78
# 53389        NaN        NaN     NaN               5          78
# 53390        NaN        NaN     NaN               6          78
# 53391        NaN        NaN     NaN               7          78
#
# [13286 rows x 10 columns]

# %% [markdown]
# # Ploting distributions of numerical data

# %%
for col in numerical.columns:
    sns.displot(numerical[col])
    plt.show()

# %%
numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13286 entries, 21 to 53391
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   yearstart    13286 non-null  int64
#  1   data_value   13286 non-null  float64
#  2   sample_size  13286 non-null  float64
#  3   locationid   13286 non-null  int64
# dtypes: float64(2), int64(2)
# memory usage: 1.0 MB

# %%
numerical.hist(figsize=(20,15), grid=False)
plt.show()

# %% [markdown]
# # Plot relationships between Numerical variables

# %%
sns.pairplot(numerical)

# %%
numerical.corr()
# Out:
#              yearstart  data_value  sample_size  locationid
# yearstart     1.000000   -0.013323     0.014043    0.047054
# data_value   -0.013323    1.000000     0.048372    0.005900
# sample_size   0.014043    0.048372     1.000000   -0.083814
# locationid    0.047054    0.005900    -0.083814    1.000000

# %%
corr = numerical.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, 
        annot=True, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['yearstart', 'locationabbr', 'locationdesc', 'data_value',
#        'sample_size', 'age(years)', 'education', 'income', 'race/ethnicity',
#        'locationid'],
#       dtype='object')

# %%
X = df[['yearstart','race/ethnicity', 'locationid']]
y = numerical['data_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
X_train.head(3)
# Out:
#        yearstart  race/ethnicity  locationid
# 9496        2014               1          17
# 36542       2015               5          28
# 25643       2011               1          41

# %% [markdown]
# # Creating the Model

# %%
# Add a constant to the independent variables for the intercept term
X = sm.add_constant(X)

# Fit the OLS regression model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             data_value   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.064
# Date:                Wed, 08 Feb 2023   Prob (F-statistic):              0.103
# Time:                        10:26:56   Log-Likelihood:                -46190.
# No. Observations:               13286   AIC:                         9.239e+04
# Df Residuals:                   13282   BIC:                         9.242e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            160.0747     80.882      1.979      0.048       1.534     318.615
# yearstart         -0.0641      0.040     -1.596      0.111      -0.143       0.015
# race/ethnicity    -0.0595      0.033     -1.807      0.071      -0.124       0.005
# locationid         0.0033      0.004      0.808      0.419      -0.005       0.011
# ==============================================================================
# Omnibus:                      448.265   Durbin-Watson:                   1.414
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1272.639
# Skew:                           0.038   Prob(JB):                    4.47e-277
# Kurtosis:                       4.514   Cond. No.                     2.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Specify the model
model = LinearRegression()

# Fit the model on the training data
model.fit(X_train, y_train)

# Predict the response on the test data
y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluating the model using mean squared error and R-squared

# %%
mse = mse(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 61.85671675255585
# R-squared: -0.0006940766155432154

# %%
#Confirming target variable = data_value
